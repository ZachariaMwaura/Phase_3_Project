# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('DATA/Traffic_Crashes_-_Crashes.csv', index_col=False)
data.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                23a79931ef555d54118f64dc9be2cf2dbf59636ce253f7...
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                09/05/2023 07:05:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                          DUSK
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                              FIVE POINT, OR MORE
# LANE_CNT                                                                     NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884221 entries, 0 to 884220
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH_RECORD_ID                884221 non-null  object
#  1   CRASH_DATE_EST_I               65448 non-null   object
#  2   CRASH_DATE                     884221 non-null  object
#  3   POSTED_SPEED_LIMIT             884221 non-null  int64
#  4   TRAFFIC_CONTROL_DEVICE         884221 non-null  object
#  5   DEVICE_CONDITION               884221 non-null  object
#  6   WEATHER_CONDITION              884221 non-null  object
#  7   LIGHTING_CONDITION             884221 non-null  object
#  8   FIRST_CRASH_TYPE               884221 non-null  object
#  9   TRAFFICWAY_TYPE                884221 non-null  object
#  10  LANE_CNT                       199017 non-null  float64
#  11  ALIGNMENT                      884221 non-null  object
# ...

# %%
data['NUM_UNITS'].value_counts()
# Out:
# NUM_UNITS
# 2     774110
# 3      48799
# 1      48515
# 4       9431
# 5       2305
# 6        657
# 7        223
# 8         99
# 9         40
# 10        18
# 11         8
# 18         5
# 12         5
# 14         2
# 16         2
# 13         1
# 15         1
# Name: count, dtype: int64

# %%
data['MOST_SEVERE_INJURY'].value_counts()
# Out:
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     758285
# NONINCAPACITATING INJURY     69707
# REPORTED, NOT EVIDENT        38448
# INCAPACITATING INJURY        14849
# FATAL                          967
# Name: count, dtype: int64

# %%
data['INJURIES_INCAPACITATING'].value_counts()
# Out:
# INJURIES_INCAPACITATING
# 0.0     867274
# 1.0      13170
# 2.0       1379
# 3.0        303
# 4.0        104
# 5.0         29
# 6.0          7
# 7.0          2
# 10.0         1
# 8.0          1
# Name: count, dtype: int64

# %% [markdown]
# ## CLEANING AND DROPPING COLUMNS

# %%
# Feature selection

data1 = data.drop(
    columns=['CRASH_RECORD_ID','CRASH_DATE_EST_I', 'CRASH_DATE', 'POSTED_SPEED_LIMIT', 'LANE_CNT', 'ALIGNMENT', 'REPORT_TYPE', 'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'DATE_POLICE_NOTIFIED', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'LATITUDE', 'LONGITUDE', 'LOCATION', 'INTERSECTION_RELATED_I']
    )

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884221 entries, 0 to 884220
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   TRAFFIC_CONTROL_DEVICE         884221 non-null  object
#  1   DEVICE_CONDITION               884221 non-null  object
#  2   WEATHER_CONDITION              884221 non-null  object
#  3   LIGHTING_CONDITION             884221 non-null  object
#  4   FIRST_CRASH_TYPE               884221 non-null  object
#  5   TRAFFICWAY_TYPE                884221 non-null  object
#  6   ROADWAY_SURFACE_COND           884221 non-null  object
#  7   ROAD_DEFECT                    884221 non-null  object
#  8   CRASH_TYPE                     884221 non-null  object
#  9   DAMAGE                         884221 non-null  object
#  10  PRIM_CONTRIBUTORY_CAUSE        884221 non-null  object
#  11  SEC_CONTRIBUTORY_CAUSE         884221 non-null  object
# ...

# %%
data1.isna().sum()
# Out:
# TRAFFIC_CONTROL_DEVICE              0
# DEVICE_CONDITION                    0
# WEATHER_CONDITION                   0
# LIGHTING_CONDITION                  0
# FIRST_CRASH_TYPE                    0
# TRAFFICWAY_TYPE                     0
# ROADWAY_SURFACE_COND                0
# ROAD_DEFECT                         0
# CRASH_TYPE                          0
# DAMAGE                              0
# PRIM_CONTRIBUTORY_CAUSE             0
# SEC_CONTRIBUTORY_CAUSE              0
# STREET_NO                           0
# STREET_DIRECTION                    4
# STREET_NAME                         1
# BEAT_OF_OCCURRENCE                  5
# NUM_UNITS                           0
# MOST_SEVERE_INJURY               1965
# INJURIES_TOTAL                   1951
# INJURIES_FATAL                   1951
# INJURIES_INCAPACITATING          1951
# INJURIES_NON_INCAPACITATING      1951
# INJURIES_REPORTED_NOT_EVIDENT    1951
# INJURIES_NO_INDICATION           1951
# INJURIES_UNKNOWN                 1951
# ...

# %%
# Drop all na

data2 = data1.dropna()

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 882247 entries, 0 to 884220
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   TRAFFIC_CONTROL_DEVICE         882247 non-null  object
#  1   DEVICE_CONDITION               882247 non-null  object
#  2   WEATHER_CONDITION              882247 non-null  object
#  3   LIGHTING_CONDITION             882247 non-null  object
#  4   FIRST_CRASH_TYPE               882247 non-null  object
#  5   TRAFFICWAY_TYPE                882247 non-null  object
#  6   ROADWAY_SURFACE_COND           882247 non-null  object
#  7   ROAD_DEFECT                    882247 non-null  object
#  8   CRASH_TYPE                     882247 non-null  object
#  9   DAMAGE                         882247 non-null  object
#  10  PRIM_CONTRIBUTORY_CAUSE        882247 non-null  object
#  11  SEC_CONTRIBUTORY_CAUSE         882247 non-null  object
# ...

# %%
# save the new file 

data2.to_csv('CLEANDATA/clean_data.csv', index=False)
